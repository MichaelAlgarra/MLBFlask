# %% [markdown]
# ### Here's some work trying to draft out this new baseball data application
#
# Ideas:
# Pybaseball batting_stats information: https://github.com/jldbc/pybaseball/blob/master/docs/batting_stats.md
# <br>
# access your application: http://127.0.0.1:5000/
# <br>
#
# scraping for minor league player data use this <br>
# https://www.fangraphs.com/leaders/minor-league?sort=23,1

# %%
from pybaseball import batting_stats
import requests
import pandas as pd

# %%
all_2022_batting_data = pybaseball.batting_stats(2022, qual=1)
all_2022_batting_data
# Out:
#       IDfg  Season               Name   Team  Age    G   AB   PA    H   1B  \
# 6    15640    2022        Aaron Judge    NYY   30  157  570  696  177   87
# 26    9777    2022      Nolan Arenado    STL   31  148  557  620  163   90
# 23   11493    2022      Manny Machado    SDP   29  150  578  644  172  102
# 17    5417    2022        Jose Altuve    HOU   32  141  527  604  158   91
# 13    9218    2022   Paul Goldschmidt    STL   34  151  561  651  178  102
# ..     ...     ...                ...    ...  ...  ...  ...  ...  ...  ...
# 505   3142    2022  Robinson Chirinos    BAL   38   67  195  220   35   22
# 575  27459    2022     Yoshi Tsutsugo    PIT   30   50  170  193   29   23
# 626  23378    2022       Jose Barrero    CIN   24   48  165  174   25   20
# 613   5491    2022      Austin Romine  - - -   33   51  129  136   20   14
# 633   3269    2022      Robinson Cano  - - -   39   33  100  104   15   13
#
# ...
